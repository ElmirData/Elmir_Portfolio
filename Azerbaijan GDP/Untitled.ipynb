# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.linear_model import LinearRegression

# %%
data= pd.read_csv('Azerbaijan GDP.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Year              33 non-null     int64
#  1    GDP Per Capita)  33 non-null     float64
#  2   Unnamed: 2        0 non-null      float64
#  3   Unnamed: 3        2 non-null      object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 1.2+ KB

# %%
sns.regplot(x="Year", y=" GDP Per Capita)", data=data)
# Out:
# <Axes: xlabel='Year', ylabel=' GDP Per Capita)'>

# %%
reg= LinearRegression()

# %%
reg=fit.(data[['Year']].values, data. GDP Per Capita)
# Out:
#   Cell In[19], line 1
#     reg=fit.(data[['Year']].values, data. GDP Per Capita)
#             ^
# SyntaxError: invalid syntax
